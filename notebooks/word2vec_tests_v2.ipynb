# %%
import pandas as pd
import numpy as np
import gensim
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import cosine_distances

# %%
df = pd.read_csv('../Datasets/df_all_linkedin.csv')
df.drop_duplicates(subset='Description', keep='first', inplace=True)
descriptions = df['Description'].values

tokenized_descriptions = []
tokenized_descriptions_tagged = []
for idx, descrip in enumerate(descriptions):
    tok_descrip = gensim.utils.simple_preprocess(descrip)
    corpus = TaggedDocument(tok_descrip, [idx])
    tokenized_descriptions_tagged.append(corpus)
    tokenized_descriptions.append(tok_descrip)

# %%
model = Doc2Vec(vector_size=100, min_count=2, epochs=50)
model.build_vocab(tokenized_descriptions_tagged)
model.train(tokenized_descriptions_tagged, total_examples=model.corpus_count, epochs=model.epochs)

vectorized_docs = []
for descrip in tokenized_descriptions:
    inferred_vec = model.infer_vector(descrip)
    vectorized_docs.append(inferred_vec)

# %%
kmeans = KMeans(n_clusters=7, n_jobs=-1)
kmeans.fit(vectorized_docs)
cluster_centers = kmeans.cluster_centers_

# %%
for idx, cluster in enumerate(cluster_centers):
    print(f"\n Cluster #{idx}: ")
    distances = euclidean_distances(cluster.reshape(1,-1), vectorized_docs)
    order = np.argsort(distances)[::-1].flatten()
    for o in order[:11]:
        print(f"Job Title: {df['Job_Title'].values[o]}, Company Name: {df['Company'].values[o]}")
# Out:
#  Cluster #0:
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Data Science Director 87614, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Scientist, Company Name: Advent Global Solutions
# Job Title: Insurance Data Scientist 84814, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Analyst, Company Name: Daasity
# Job Title: Data Scientist, Company Name: JNIT Technologies
# Job Title: Insurance Data Scientist 86679, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Scientist II -Broomfield, Company Name: Sparity
# Job Title: Data Scientist II, Company Name: Sparity
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
#
#  Cluster #1:
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Data Scientist, Company Name: Advent Global Solutions
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Data Scientist II -Broomfield, Company Name: Sparity
# Job Title: Insurance Data Scientist 84814, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Scientist - Tampa, FL, Company Name: Themesoft Inc.
# Job Title: Data Scientist -Tampa, Company Name: Themesoft Inc.
# Job Title: Data Science / Machine Learning Engineer, Company Name: Ultimo Software Solutions
# Job Title: Data Scientist II, Company Name: Sparity
#
#  Cluster #2:
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Data Scientist, Company Name: Advent Global Solutions
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Data Science Director 87614, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Director of Data Science, Company Name: Harnham
# Job Title: Insurance Data Scientist 84814, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Scientist II -Broomfield, Company Name: Sparity
# Job Title: Insurance Data Scientist 86679, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Science / Machine Learning Engineer, Company Name: Ultimo Software Solutions
#
#  Cluster #3:
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Data Scientist, Company Name: Advent Global Solutions
# Job Title: Insurance Data Scientist 84814, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Data Scientist II -Broomfield, Company Name: Sparity
# Job Title: Insurance Data Scientist 86679, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Science Director 87614, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Scientist, Company Name: JNIT Technologies
# Job Title: Data Scientist II, Company Name: Sparity
#
#  Cluster #4:
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Rochester Data Science Consortium Intern - 217410, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219225, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern - 217411, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219224, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219226, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV, Company Name: University of Rochester
# Job Title: Data Scientist, Company Name: Advent Global Solutions
# Job Title: Rochester Data Science Consortium Intern IV - 219224 - University of Rochester, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219225 - University of Rochester, Company Name: University of Rochester
#
#  Cluster #5:
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Data Scientist - Tampa, FL, Company Name: Themesoft Inc.
# Job Title: Data Scientist, Company Name: Advent Global Solutions
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Data Scientist -Tampa, Company Name: Themesoft Inc.
# Job Title: Data Scientist II -Broomfield, Company Name: Sparity
# Job Title: Director of Data Science, Company Name: Harnham
# Job Title: Data Science Director 87614, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Science / Machine Learning Engineer, Company Name: Ultimo Software Solutions
#
#  Cluster #6:
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Director of Data Science, Company Name: Harnham
# Job Title: Data Scientist, Company Name: Advent Global Solutions
# Job Title: Data Scientist - Tampa, FL, Company Name: Themesoft Inc.
# Job Title: Data Science / Machine Learning Engineer, Company Name: Ultimo Software Solutions
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Data Scientist II -Broomfield, Company Name: Sparity
# Job Title: Python Data Developer, Company Name: Scaled Outcomes, LLC
# Job Title: Data Scientist -Tampa, Company Name: Themesoft Inc.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job_Title', 'Company', 'Location',
#        'Number_of_Applicants', 'Description', 'Length_of_Description',
#        'Senior', 'Junior', 'Senior_Junior_or_not', 'num_applicants', 'State'],
#       dtype='object')

# %%
for idx, cluster in enumerate(cluster_centers):
    print(f"\n Cluster #{idx}: ")
    distances = cosine_distances(cluster.reshape(1,-1), vectorized_docs)
    order = np.argsort(distances)[::-1].flatten()
    for o in order[:11]:
        print(f"Job Title: {df['Job_Title'].values[o]}, Company Name: {df['Company'].values[o]}")
# Out:
#  Cluster #0:
# Job Title: Data Coordinator (Melanoma) (Open Rank), Company Name: University of Colorado
# Job Title: Clinical Research Coordinator (Phase 1), Company Name: University of Colorado
# Job Title: Data Analyst-Statistical-Castell, Company Name: Intermountain Healthcare
# Job Title: Data Analyst, Company Name: University of Colorado
# Job Title: Health Data Analyst/BI Developer, Company Name: University of Colorado
# Job Title: Scientist-Sr., Healthcare Delivery Institute - Intermountain Medical Center - Full time, Company Name: Intermountain Healthcare
# Job Title: Data Analytics & Business Intelligence Developer, Company Name: University of Colorado
# Job Title: Data Scientist - Behavioral Health, Company Name: Denver Health
# Job Title: Data Analyst- Staff/Sr at Primary Children's Hospital, Company Name: Intermountain Healthcare
# Job Title: Data Management Analyst II, Company Name: University of Florida
# Job Title: Data Analytics AVP - Clinical Analytics, Company Name: Intermountain Healthcare
#
#  Cluster #1:
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Apple Podcasts Data Scientist, Apple Media Products Data Science, Company Name: Apple
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: App Store Business Data Scientist, Apple Media Products Data Science, Company Name: Apple
# Job Title: Business Data Scientist, Apple Media Products Data Science, Company Name: Apple
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Data Scientist - Forecasting, Company Name: Amazon
# Job Title: Data Scientist II -Broomfield, Company Name: Sparity
# Job Title: Data Scientist - Forecasting, Company Name: Amazon
# Job Title: Product Manager, Company Name: Progressive Leasing
#
#  Cluster #2:
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Associate, Big Data Software Engineer, Company Name: KPMG US
# Job Title: Manager, Data & Analytics, Company Name: KPMG US
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Manager, Intelligent Automation, Company Name: KPMG US
# Job Title: Associate, Data Engineer, Company Name: KPMG US
# Job Title: Director, Data Analytics, Company Name: ROYAL CARIBBEAN CRUISE LINE A/S
# Job Title: Manager, SAP Analytics, Company Name: KPMG US
# Job Title: Director, Data Analytics, Company Name: Royal Caribbean Cruises Ltd.
# Job Title: Associate, Data Engineer, Company Name: KPMG US
#
#  Cluster #3:
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Data Scientist II -Broomfield, Company Name: Sparity
# Job Title: Insurance Data Scientist 84814, Company Name: Ezra Penland Actuarial Recruitment
# Job Title: Data Engineer 5 - Contract, Company Name: The Church of Jesus Christ of Latter-day Saints
# Job Title: Data Engineer 5 - Contract (Remote), Company Name: Church Of Jesus Christ Of Latterday Saints Jar
# Job Title: Data Engineer 5 - Contract, Company Name: The Church of Jesus Christ of Latter-day Saints
# Job Title: Data Engineer 5 - Contract, Company Name: Church Of Jesus Christ Of Latterday Saints Jar
# Job Title: Data Engineer 5 - Contract, Company Name: Church Of Jesus Christ Of Latterday Saints Jar
#
#  Cluster #4:
# Job Title: Rochester Data Science Consortium Intern - 217410, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219225, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern - 217411, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219224, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219226, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219225 - University of Rochester, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219224 - University of Rochester, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern IV - 219226 - University of Rochester, Company Name: University of Rochester
# Job Title: Rochester Data Science Consortium Intern - 217411 - University of Rochester, Company Name: University of Rochester
# Job Title: Data Scientist, Company Name: Pacific Northwest National Laboratory - PNNL
#
#  Cluster #5:
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Data Scientist - Tampa, FL, Company Name: Themesoft Inc.
# Job Title: Data Scientist -Tampa, Company Name: Themesoft Inc.
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
# Job Title: Data Scientist - Tampa, FL, Company Name: Themesoft Inc.
# Job Title: Data Scientist II -Broomfield, Company Name: Sparity
# Job Title: Data Scientist II, Company Name: SMX
# Job Title: Data Science Manager, Company Name: The Job Network
# Job Title: Data Science Manager, Company Name: Harnham
# Job Title: Data Science Manager, Company Name: Harnham
#
#  Cluster #6:
# Job Title: iOS Engineer, Intern, Company Name: Ancestry
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Quality Engineer, Intern, Company Name: Ancestry
# Job Title: Machine Learning Engineer, Company Name: Next Level Business Services, Inc.
# Job Title: Android Engineer, Intern, Company Name: Ancestry
# Job Title: Development & Operations Engineer, Intern, Company Name: Ancestry
# Job Title: Software Engineer Intern (Big Tree Team), Company Name: Ancestry
# Job Title: Data Science Engineer, Intern, Company Name: The Job Network
# Job Title: Back-end/Middleware Software Engineer, Intern, Company Name: Ancestry
# Job Title: Data Engineer, Intern, Company Name: Ancestry
# Job Title: Data Scientist -Tampa, Company Name: Advent Global Solutions
